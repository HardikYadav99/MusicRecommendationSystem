# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/music reccomendation/spotify_millsongdata.csv")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df = df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df['text'][0]
# Out:
# "Make sure!  \r\nTaking cover in the bunker tonight  \r\nWaiting for Bo Diddley's headlights  \r\nI feel alright  \r\nGotta Fender Stratosphere  \r\nI can do anything tonight  \r\nIt's in neon lights an' global rights  \r\nFrank? He's on the phone  \r\nThere ain't no German girl outside  \r\nBut who cares when its warm inside?  \r\nWith music  \r\nSpecial mystery of music tragically  \r\nExchanging slaves for majesties  \r\nModern waves of tragedy  \r\nPacking a two piece colt pair of shoots  \r\nA shiny grey Mexican suit  \r\nThe blue eyed traffic can sashay by  \r\n'Cause tonight the sailor boys have hit Shanghai  \r\nThe kick-out traffic goes creaking by  \r\nI smash my glass and shout shanghai  \r\nMy drummer friend comes shooting by  \r\nHe said Errol Flynn will never die  \r\nOh no! Who am I to question why?  \r\nAnd are you lonesome tonight  \r\nAnd do ya need a country cowboy  \r\nWho's just thin and tight in those  \r\nBr' bus depot jeans  \r\nWith a squirt resistant stud st
# ...

# %%
df['text'] =df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n',' ',regex = True)

# %%
df.tail(5)
# Out:
#                   artist                                    song  \
# 4995           Rammstein     Rammstein (Rammbling Stone) English
# 4996          Chaka Khan                         I'm Every Woman
# 4997      Isley Brothers                              Inside You
# 4998  Christina Aguilera  Have Yourself A Merry Little Christmas
# 4999             Xandria               In Love With The Darkness
#
#                                                    text
# 4995  rammstein  \r a human burns  \r rammstein  \r ...
# 4996  whatever you want,  \r whatever you need,  \r ...
# 4997  baby, just stay with me a little longer  \r ba...
# 4998  have yourself a merry little christmas  \r let...
# 4999  no more tears  \r i'm out of fears  \r i'm out...

# %%
pip install --upgrade nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
pip install --upgrade scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import nltk
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
  token = nltk.word_tokenize(txt)
  a =[stemmer.stem(w) for w in token]
  return " ".join(a)

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 0       make sure ! take cover in the bunker tonight w...
# 1       all my life i 'm wait for you mysteri , fate a...
# 2       oh babi , what a place to be in the servic of ...
# 3       you were born togeth and togeth ye shall be fo...
# 4       i date siames twin i slept with bigfoot , too ...
#                               ...
# 4995    rammstein a human burn rammstein the smell of ...
# 4996    whatev you want , whatev you need , anyth you ...
# 4997    babi , just stay with me a littl longer babi ,...
# 4998    have yourself a merri littl christma let your ...
# 4999    no more tear i 'm out of fear i 'm out of pain...
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
matrix=tfidf.fit_transform(df['text'])

# %%
similer = cosine_similarity(matrix)

# %%
similer[0]
# Out:
# array([1.        , 0.03358934, 0.04435816, ..., 0.04162696, 0.00885737,
#        0.01366733])

# %%
# Filter the DataFrame based on the song title
filtered_df = df[df['song'] == 'Bang']

# Check if any rows match the condition
if not filtered_df.empty:
    # If there are matching rows, access the index of the first one
    song_index = filtered_df.index[0]
    print(f"The song 'Bang' is found at index {song_index}.")
else:
    print("The song 'Bang' was not found in the DataFrame.")
# Out:
# The song 'Bang' is found at index 854.

# %%
def reccomender(song_name):
  df[df['song'] == 'As Good As New']

# %%
df[df['song'] == "Me And Bobby And Bobby's Brother"]
# Out:
# Empty DataFrame
# Columns: [artist, song, text]
# Index: []

# %%
print(df)
# Out:
#                   artist                                    song  \
# 0                  Clash                     If Music Could Talk
# 1              Ofra Haza                  Mystery, Fate And Love
# 2               Iggy Pop                             Endless Sea
# 3             Jason Mraz                     God Rests In Reason
# 4      Weird Al Yankovic                               Talk Soup
# ...                  ...                                     ...
# 4995           Rammstein     Rammstein (Rammbling Stone) English
# 4996          Chaka Khan                         I'm Every Woman
# 4997      Isley Brothers                              Inside You
# 4998  Christina Aguilera  Have Yourself A Merry Little Christmas
# 4999             Xandria               In Love With The Darkness
#
#                                                    text
# 0     make sure!  \r taking cover in the bunker toni...
# 1     all my life i'm waiting for you  \r mystery, f...
# ...

# %%
filtered_df = df[df['song'] == 'Bang-A-Boomerang']
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [artist, song, text]
# Index: []

# %%
df['song'] = df['song'].str.strip()  # Remove leading/trailing whitespaces
per=df[df['artist'] == 'ABBA']
print(per)
# Out:
#      artist                         song  \
# 700    ABBA  The King Has Lost His Crown
# 845    ABBA               Every Good Man
# 876    ABBA             I'm A Marionette
# 1514   ABBA     Givin' A Little Bit More
# 2578   ABBA        Pick A Bale Of Cotton
# 2766   ABBA           Love Has It's Ways
# 2785   ABBA   Put On Your White Sombrero
# 2996   ABBA               Dum Dum Diddle
# 3691   ABBA                   Hamlet III
# 4047   ABBA               Reina Danzante
#
#                                                    text
# 700   i believe your new girl turned you down  \r an...
# 845   every good man needs a helping hand  \r so i t...
# 876   you're so free  \r that's what everybody's tel...
# 1514  there's a gentleness to everything you do  \r ...
# 2578  gonna jump down  \r spin around  \r pick a bal...
# 2766  spring in the air  \r the sun was shining  \r ...
# 2785  put on your white sombrero  \r saddle your hor...
# 2996  i can hear how you work, practising hard  \r p...
# ...

# %%
print(df['song'].unique())
# Out:
# ['If Music Could Talk' 'Mystery, Fate And Love' 'Endless Sea' ...
#  "I'm Every Woman" 'Inside You' 'In Love With The Darkness']

# %%
unique_song_names = df['song'].unique()
print(unique_song_names)
# Out:
# ['If Music Could Talk' 'Mystery, Fate And Love' 'Endless Sea' ...
#  "I'm Every Woman" 'Inside You' 'In Love With The Darkness']

# %%
song_name = 'Bang-A-Boomerang'
df[df['song'].str.strip() == song_name.strip()]
# Out:
# Empty DataFrame
# Columns: [artist, song, text]
# Index: []

# %%
df.head(3400)
# Out:
#                  artist                        song  \
# 0                 Clash         If Music Could Talk
# 1             Ofra Haza      Mystery, Fate And Love
# 2              Iggy Pop                 Endless Sea
# 3            Jason Mraz         God Rests In Reason
# 4     Weird Al Yankovic                   Talk Soup
# ...                 ...                         ...
# 3395       Bette Midler                   Superstar
# 3396     Ellie Goulding                  Explosions
# 3397       Wishbone Ash                  Persephone
# 3398            Hollies                Give Me Time
# 3399       Bette Midler  My Knight In Black Leather
#
#                                                    text
# 0     make sure!  \r taking cover in the bunker toni...
# 1     all my life i'm waiting for you  \r mystery, f...
# 2     oh baby, what a place to be  \r in the service...
# 3     you were born together and together ye shall b...
# ...

# %%
unique_song_names = df['song'].unique()[:20]  # Display the first 20 unique song names
print(unique_song_names)
# Out:
# ['If Music Could Talk' 'Mystery, Fate And Love' 'Endless Sea'
#  'God Rests In Reason' 'Talk Soup' 'Race Car Ya-Yas'
#  '(Theme) Once Upon A Time' 'Away In A Manger' 'Choking Tara'
#  'Have Yourself A Merry Little Christmas' 'Missionary Man' 'Dirty Magic'
#  'Fire Dance' 'You Need Love' 'The Final Spark' 'Ghetto Love Story'
#  'Oh Ms Believer' 'Keep All That Junk To Yourself' 'Lost Again'
#  'Goddamn Devil']

# %%
first_20_songs = df['song'].iloc[:20]
print(first_20_songs)
# Out:
# 0                        If Music Could Talk
# 1                     Mystery, Fate And Love
# 2                                Endless Sea
# 3                        God Rests In Reason
# 4                                  Talk Soup
# 5                            Race Car Ya-Yas
# 6                   (Theme) Once Upon A Time
# 7                           Away In A Manger
# 8                               Choking Tara
# 9     Have Yourself A Merry Little Christmas
# 10                            Missionary Man
# 11                               Dirty Magic
# 12                                Fire Dance
# 13                             You Need Love
# 14                           The Final Spark
# 15                         Ghetto Love Story
# 16                            Oh Ms Believer
# 17            Keep All That Junk To Yourself
# 18                                Lost Again
# 19                             Goddamn Devil
# Name: song, dtype: object

# %%
df.head(5)
# Out:
#               artist                    song  \
# 0              Clash     If Music Could Talk
# 1          Ofra Haza  Mystery, Fate And Love
# 2           Iggy Pop             Endless Sea
# 3         Jason Mraz     God Rests In Reason
# 4  Weird Al Yankovic               Talk Soup
#
#                                                 text
# 0  make sure!  \r taking cover in the bunker toni...
# 1  all my life i'm waiting for you  \r mystery, f...
# 2  oh baby, what a place to be  \r in the service...
# 3  you were born together and together ye shall b...
# 4  i dated siamese twins  \r i slept with bigfoot...

# %%
first_20_songs = df['song'].iloc[:50]
print(first_20_songs)
# Out:
# 0                        If Music Could Talk
# 1                     Mystery, Fate And Love
# 2                                Endless Sea
# 3                        God Rests In Reason
# 4                                  Talk Soup
# 5                            Race Car Ya-Yas
# 6                   (Theme) Once Upon A Time
# 7                           Away In A Manger
# 8                               Choking Tara
# 9     Have Yourself A Merry Little Christmas
# 10                            Missionary Man
# 11                               Dirty Magic
# 12                                Fire Dance
# 13                             You Need Love
# 14                           The Final Spark
# 15                         Ghetto Love Story
# 16                            Oh Ms Believer
# 17            Keep All That Junk To Yourself
# 18                                Lost Again
# 19                             Goddamn Devil
# 20                       Ballad Of Flo'Z Kid
# ...

# %%
df[df['song']== "Don't Get Around Much Anymore"].index[0]
# Out:
# 25

# %%
def recommender(song_name):
  idx = df[df['song']==song_name].index[0]
  distance = sorted(list(enumerate(similer[idx])),reverse=True, key = lambda x:x[1])
  song = []
  for s_id in distance[0:10]:
    song.append(df.iloc[s_id[0]].song)

  return song

# %%
recommender("The Final Spark")
# Out:
# ['The Final Spark',
#  'I Will Follow',
#  'Country Is As Country Does',
#  'Way Of Life',
#  'The Perfect Fan',
#  "Don't Look Down",
#  'Country Willie',
#  'Myself Without You',
#  'Not Enough Romance',
#  'Best You Can Get']

# %%
df.tail(5)
# Out:
#                   artist                                    song  \
# 4995           Rammstein     Rammstein (Rammbling Stone) English
# 4996          Chaka Khan                         I'm Every Woman
# 4997      Isley Brothers                              Inside You
# 4998  Christina Aguilera  Have Yourself A Merry Little Christmas
# 4999             Xandria               In Love With The Darkness
#
#                                                    text
# 4995  rammstein  \r a human burns  \r rammstein  \r ...
# 4996  whatever you want,  \r whatever you need,  \r ...
# 4997  baby, just stay with me a little longer  \r ba...
# 4998  have yourself a merry little christmas  \r let...
# 4999  no more tears  \r i'm out of fears  \r i'm out...
